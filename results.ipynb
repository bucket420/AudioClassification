# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython import display
import importlib
import numpy as np
import pandas as pd
import utils

# %%
audio_test = tf.saved_model.load("data/processed/audio_test").read_value()

# %%
sources = ["acoustic", "electronic", "synthetic"]
families = ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "synth_lead", "vocal"]

# %%
instr_cnn = tf.keras.models.load_model("models/instr_cnn")
instr_lr = tf.keras.models.load_model("models/instr_lr")
src_cnn = tf.keras.models.load_model("models/src_cnn")
src_lr = tf.keras.models.load_model("models/src_lr")

# %%
instr_cnn_history = pd.read_json("training_history/instr_cnn.json")
instr_lr_history = pd.read_json("training_history/instr_lr.json")
src_cnn_history = pd.read_json("training_history/src_cnn.json")
src_lr_history = pd.read_json("training_history/src_lr.json")

# %%
utils.plot_history(instr_cnn_history)

# %%
utils.plot_history(instr_lr_history)

# %%
utils.plot_history(src_cnn_history)

# %%
utils.plot_history(src_lr_history)

# %%
utils.predict(instr_cnn, audio_test[0], families)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 1/1 [==============================] - 0s 35ms/step
# Predicted class: keyboard
# 'keyboard'
